# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('/Users/akshay/Downloads/ecommerce/seeds/ecom_data.csv')

# %%
col =

# %%
new_df = df.loc[:100].dropna(axis=1)

# %%
new_df[['prices.amountMax','name', 'primaryCategories','imageURLs','categories','brand','weight','prices.merchant',]]
# Out:
#      prices.amountMax                                               name  \
# 0              104.99  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1               69.00  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2               69.00  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3               69.99  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 4               66.99  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# ..                ...                                                ...
# 96              22.99  Samsung Universal 3100mAh Portable External Ba...
# 97              14.84  Samsung Universal 3100mAh Portable External Ba...
# 98              17.99  Samsung Universal 3100mAh Portable External Ba...
# 99              49.00  Air-Fi Runaway AF32 Stereo Bluetooth Wireless ...
# 100             34.99  Air-Fi Runaway AF32 Stereo Bluetooth Wireless ...
#
#     primaryCategories                                          imageURLs  \
# ...

# %%
new_df.assign(description = lambda x: f"This product is made by {x['brand']}, it weighs {x['weight']} and is sold by {x['prices.merchant']} \n Categories: {x['categories']}" )
# Out:
#                        id  prices.amountMax  prices.amountMin  \
# 0    AVphzgbJLJeJML43fA0o            104.99            104.99
# 1    AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2    AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3    AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4    AVpgMuGwLJeJML43KY_c             66.99             66.99
# ..                    ...               ...               ...
# 96   AVpgnnzJilAPnD_xu_7Q             22.99             22.99
# 97   AVpgnnzJilAPnD_xu_7Q             14.84             14.84
# 98   AVpgnnzJilAPnD_xu_7Q             17.99             17.99
# 99   AVpfyGvu1cnluZ0-rMw9             49.00             49.00
# 100  AVpfyGvu1cnluZ0-rMw9             34.99             34.99
#
#     prices.availability prices.condition prices.currency  \
# 0                   Yes              New             USD
# 1              In Stock              New             USD
# ...
